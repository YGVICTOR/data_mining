# %% [markdown]
# # Clustering

# %%
import sklearn.datasets as data
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import random

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 新版本已经没有samples_generator

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X, clusters = data.make_blobs(n_samples=1000,n_features=2,cluster_std=1.0,random_state=3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
figure = plt.figure()
plt.scatter(X[:,0],X[:,1],color='green')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3 Write K-Means Yourself

# %%
n = X.shape[0]
random.
c1_x = random.randint(0,n-1)
c1_y = random.randint(0,n-1)
c2_x = random.randint(0,n-1)
c2_y = random.randint(0,n-1)

# %%
# Out:
# 2
